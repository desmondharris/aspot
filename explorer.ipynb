# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from dotenv import load_dotenv
from os import getenv 
from constants import *
load_dotenv()
# Out:
# True

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=getenv('CLIENT_ID'), client_secret=getenv('CLIENT_SECRET'),
    redirect_uri=getenv('REDIRECT_URI'),scope=SPOTIPY_DEFAULT_SCOPE))
results = sp.current_user_saved_tracks(offset=0, limit=50)

# %%
results
# Out:
# {'href': 'https://api.spotify.com/v1/me/tracks?offset=0&limit=50',
#  'items': [{'added_at': '2025-03-07T17:33:52Z',
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ycnb8Er79LoH2AsR5ldjh'},
#        'href': 'https://api.spotify.com/v1/artists/2ycnb8Er79LoH2AsR5ldjh',
#        'id': '2ycnb8Er79LoH2AsR5ldjh',
#        'name': 'Pet Shop Boys',
#        'type': 'artist',
#        'uri': 'spotify:artist:2ycnb8Er79LoH2AsR5ldjh'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
# ...

# %%
results['items'][0]
# Out:
# {'added_at': '2025-03-07T17:33:52Z',
#  'track': {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ycnb8Er79LoH2AsR5ldjh'},
#      'href': 'https://api.spotify.com/v1/artists/2ycnb8Er79LoH2AsR5ldjh',
#      'id': '2ycnb8Er79LoH2AsR5ldjh',
#      'name': 'Pet Shop Boys',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ycnb8Er79LoH2AsR5ldjh'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/47fRf3JwriMUPPzFjdvNS6'},
#    'href': 'https://api.spotify.com/v1/albums/47fRf3JwriMUPPzFjdvNS6',
#    'id': '47fRf3JwriMUPPzFjdvNS6',
#    'images': [{'height': 640,
#      'width': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2733540f5cb8e1e7a54125f84db'},
#     {'height': 300,
#      'width': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e023540f5cb8e1e7a54125f84db'},
#     {'height': 64,
#      'width': 64,
# ...

# %%
results['items'][0]['track']['album'].pop('available_markets')
# Out:
# ['AR',
#  'AU',
#  'AT',
#  'BE',
#  'BO',
#  'BR',
#  'BG',
#  'CA',
#  'CL',
#  'CO',
#  'CR',
#  'CY',
#  'CZ',
#  'DK',
#  'DO',
#  'DE',
#  'EC',
#  'EE',
#  'SV',
#  'FI',
#  'FR',
#  'GR',
#  'GT',
#  'HN',
#  'HK',
#  'HU',
#  'IS',
#  'IE',
#  'IT',
#  'LV',
#  'LT',
#  'LU',
#  'MY',
#  'MT',
#  'MX',
#  'NL',
#  'NZ',
#  'NI',
#  'NO',
#  'PA',
#  'PY',
#  'PE',
#  'PH',
#  'PL',
#  'PT',
#  'SG',
#  'SK',
#  'ES',
#  'SE',
#  'CH',
#  'TW',
#  'TR',
#  'UY',
#  'US',
#  'GB',
#  'AD',
#  'LI',
#  'MC',
#  'ID',
#  'JP',
#  'TH',
#  'VN',
#  'RO',
#  'IL',
#  'ZA',
#  'SA',
#  'AE',
#  'BH',
#  'QA',
#  'OM',
#  'KW',
#  'EG',
#  'MA',
#  'DZ',
#  'TN',
#  'LB',
#  'JO',
#  'PS',
#  'IN',
#  'BY',
#  'KZ',
#  'MD',
#  'UA',
#  'AL',
#  'BA',
#  'HR',
#  'ME',
#  'MK',
#  'RS',
#  'SI',
#  'KR',
#  'BD',
#  'PK',
#  'LK',
#  'GH',
#  'KE',
#  'NG',
#  'TZ',
#  'UG',
#  'AG',
#  'AM',
#  'BS',
#  'BB',
#  'BZ',
#  'BT',
#  'BW',
#  'BF',
#  'CV',
#  'CW',
#  'DM',
#  'FJ',
# ...

# %%
results['items'][0]['track'].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])
